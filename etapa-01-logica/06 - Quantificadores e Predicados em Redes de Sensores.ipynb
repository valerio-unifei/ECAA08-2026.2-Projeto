# %% [markdown]
# # Aula 06 - Notebook: Lógica de Predicados e Quantificadores em Redes de Sensores
#
# Neste notebook implementamos a avaliação de predicados unários e binários e os quantificadores $orall$ (*FORALL*) e $\exists$ (*EXISTS*) sobre coleções de sensores distribuídos na planta industrial.

# %%
def formatar_tabela(dados):
    """Formata lista de dicionarios em tabela ASCII pura."""
    if not dados:
        return "Tabela Vazia"
    colunas = list(dados[0].keys())
    larguras = {c: len(str(c)) for c in colunas}
    for row in dados:
        for c in colunas:
            larguras[c] = max(larguras[c], len(str(row.get(c, ""))))
    header = " | ".join(f"{c:<{larguras[c]}}" for c in colunas)
    divisor = "-+-".join("-" * larguras[c] for c in colunas)
    linhas = [header, divisor]
    for row in dados:
        linhas.append(" | ".join(f"{str(row.get(c, '')):<{larguras[c]}}" for c in colunas))
    return "\n".join(linhas)

from dataclasses import dataclass
from typing import List, Callable, Any

@dataclass
class SensorProcesso:
    tag: str
    setor: str
    tipo: str
    valor: float
    unidade: str
    limite: float
    falha_comunicacao: bool = False

def FORALL(dominio: List[Any], predicado: Callable[[Any], bool]) -> bool:
    return all(predicado(x) for x in dominio)

def EXISTS(dominio: List[Any], predicado: Callable[[Any], bool]) -> bool:
    return any(predicado(x) for x in dominio)

rede_sensores = [
    SensorProcesso('AT-101A', 'Setor 100', 'GAS_NH3', 4.5, 'ppm', 25.0),
    SensorProcesso('AT-101B', 'Setor 100', 'GAS_NH3', 6.2, 'ppm', 25.0),
    SensorProcesso('AT-101C', 'Setor 100', 'GAS_NH3', 32.0, 'ppm', 25.0),
    SensorProcesso('PT-101A', 'Setor 100', 'PRESSAO', 140.0, 'bar', 180.0),
]

detectores_gas = [s for s in rede_sensores if s.tipo == 'GAS_NH3']
existe_vazamento = EXISTS(detectores_gas, lambda s: s.valor >= s.limite)
todos_comunicando = FORALL(rede_sensores, lambda s: not s.falha_comunicacao)

print(f"1. Existe Vazamento de Gás (EXISTS): {existe_vazamento}")
print(f"2. Todos Sensores Comunicando (FORALL): {todos_comunicando}")

tabela = [{"Tag": s.tag, "Setor": s.setor, "Valor": f"{s.valor} {s.unidade}", "Limite": f"{s.limite} {s.unidade}", "Falha": s.valor >= s.limite} for s in rede_sensores]
print("\n" + formatar_tabela(tabela))
assert existe_vazamento is True
# Out:
# 1. Existe Vazamento de Gás (EXISTS): True
# 2. Todos Sensores Comunicando (FORALL): True
#
# Tag     | Setor     | Valor     | Limite    | Falha
# --------+-----------+-----------+-----------+------
# AT-101A | Setor 100 | 4.5 ppm   | 25.0 ppm  | False
# AT-101B | Setor 100 | 6.2 ppm   | 25.0 ppm  | False
# AT-101C | Setor 100 | 32.0 ppm  | 25.0 ppm  | True
# PT-101A | Setor 100 | 140.0 bar | 180.0 bar | False
